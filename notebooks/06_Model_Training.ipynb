# %%
# ==========================================
# Fake News Detection Using NLP
# Phase 6 - Model Training
# ==========================================

import pandas as pd
import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score

# %%
X_train = joblib.load("../models/X_train.pkl")
X_test = joblib.load("../models/X_test.pkl")

y_train = joblib.load("../models/y_train.pkl")
y_test = joblib.load("../models/y_test.pkl")

print("Training Shape :", X_train.shape)
print("Testing Shape :", X_test.shape)
# Out:
# Training Shape : (35345, 5000)
# Testing Shape : (8837, 5000)

# %%
print("="*60)
print("Training Logistic Regression")
print("="*60)

lr = LogisticRegression(max_iter=1000)

lr.fit(X_train, y_train)

lr_pred = lr.predict(X_test)

lr_acc = accuracy_score(y_test, lr_pred)

print("Accuracy :", round(lr_acc*100,2), "%")
# Out:
# ...
# Training Logistic Regression
# ...
# Accuracy : 98.97 %

# %%
print("="*60)
print("Training Naive Bayes")
print("="*60)

nb = MultinomialNB()

nb.fit(X_train, y_train)

nb_pred = nb.predict(X_test)

nb_acc = accuracy_score(y_test, nb_pred)

print("Accuracy :", round(nb_acc*100,2), "%")
# Out:
# ...
# Training Naive Bayes
# ...
# Accuracy : 94.25 %

# %%
print("="*60)
print("Training Decision Tree")
print("="*60)

dt = DecisionTreeClassifier(random_state=42)

dt.fit(X_train, y_train)

dt_pred = dt.predict(X_test)

dt_acc = accuracy_score(y_test, dt_pred)

print("Accuracy :", round(dt_acc*100,2), "%")
# Out:
# ...
# Training Decision Tree
# ...
# Accuracy : 99.51 %

# %%
print("="*60)
print("Training Random Forest")
print("="*60)

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

rf_acc = accuracy_score(y_test, rf_pred)

print("Accuracy :", round(rf_acc*100, 2), "%")
# Out:
# ...
# Training Random Forest
# ...
# Accuracy : 99.82 %

# %%
import joblib
import os

os.makedirs("../models", exist_ok=True)

# Save Random Forest Model
joblib.dump(rf, "../models/random_forest_model.pkl")


print("="*60)
print("Model Saving")
print("="*60)
print("Random Forest Model Saved Successfully.")
print("TF-IDF Vectorizer Saved Successfully.")
# Out:
# ...
# Model Saving
# ...
# Random Forest Model Saved Successfully.
# TF-IDF Vectorizer Saved Successfully.

# %%
print("="*60)
print("Training Support Vector Machine")
print("="*60)

svm = LinearSVC()

svm.fit(X_train, y_train)

svm_pred = svm.predict(X_test)

svm_acc = accuracy_score(y_test, svm_pred)

print("Accuracy :", round(svm_acc*100,2), "%")
# Out:
# ...
# Training Support Vector Machine
# ...
# Accuracy : 99.63 %

# %%
results = pd.DataFrame({

    "Model":[
        "Logistic Regression",
        "Naive Bayes",
        "Decision Tree",
        "Random Forest",
        "Support Vector Machine"
    ],

    "Accuracy":[

        lr_acc*100,

        nb_acc*100,

        dt_acc*100,

        rf_acc*100,

        svm_acc*100
    ]

})

results = results.sort_values(
    by="Accuracy",
    ascending=False
)

results
# Out:
#                     Model   Accuracy
# 3           Random Forest  99.818943
# 4  Support Vector Machine  99.626570
# 2           Decision Tree  99.513410
# 0     Logistic Regression  98.970239
# 1             Naive Bayes  94.251443

# %%
joblib.dump(
    rf,
    "../models/fake_news_model.pkl"
)

print("Random Forest Model Saved Successfully.")
# Out:
# Random Forest Model Saved Successfully.

# %%
print("="*60)
print("Model Training Observations")
print("="*60)

print("1. Successfully trained five machine learning classification models.")
print("2. Compared model performance using prediction accuracy.")
print("3. Random Forest achieved the highest accuracy of 99.82%.")
print("4. Support Vector Machine and Decision Tree also demonstrated excellent performance.")
print("5. Naive Bayes produced the lowest accuracy among the evaluated models.")
print("6. The best-performing Random Forest model has been saved for future predictions.")
print("7. The project is now ready for detailed model evaluation.")

print("\nModel Training Completed Successfully.")
# Out:
# ...
# Model Training Observations
# ...
# 1. Successfully trained five machine learning classification models.
# 2. Compared model performance using prediction accuracy.
# 3. Random Forest achieved the highest accuracy of 99.82%.
# 4. Support Vector Machine and Decision Tree also demonstrated excellent performance.
# 5. Naive Bayes produced the lowest accuracy among the evaluated models.
# 6. The best-performing Random Forest model has been saved for future predictions.
# 7. The project is now ready for detailed model evaluation.
#
# Model Training Completed Successfully.

# %%
import joblib
import os

os.makedirs("../models", exist_ok=True)

# Save Random Forest Model
joblib.dump(rf, "../models/random_forest_model.pkl")

print("Random Forest Model Saved Successfully.")
# Out:
# Random Forest Model Saved Successfully.

# %%
print(type(rf))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
